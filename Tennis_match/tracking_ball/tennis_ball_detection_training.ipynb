# %% [markdown]
# ##get dataset

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="MDvDyBM2E7QnXpuMmIep")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")

# %%
import shutil
from ultralytics import YOLO

# %%
shutil.move("tennis-ball-detection-6/train",
            "tennis-ball-detection-6/tennis-ball-detecton-6/train",
            )

shutil.move("tennis-ball-detection-6/test",
            "tennis-ball-detection-6/tennis-ball-detecton-6/test",
            )

shutil.move("tennis-ball-detection-6/valid",
            "tennis-ball-detection-6/tennis-ball-detecton-6/valid",
            )
# Out:
# 'tennis-ball-detection-6/tennis-ball-detecton-6/valid'

# %%
# !yolo task=detect mode=train model=yolov5n.pt data='/luidhy_docker/DELVEIMAGENS/other_things/tenis/training/tennis-ball-detection-6/data.yaml' epochs=100 imgsz=640 workers=0 batch=2
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.3.9 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA RTX A5000, 24241MiB)
# ...
